# %% [markdown]
# !pip install --upgrade pip
# !pip cache clear
# !pip install pyshp

# %% [markdown]
# !pip install numpy
# !pip install geopandas

# %% [markdown]
# !pip install pyshp

# %%
import geopandas as gpd
# Read shp data of Taiwan county 
# 縣市界
County_data = gpd.read_file("C:/Users/Huwalli/OneDrive/文件/GitHub/eduproject/mapdata202301070205/COUNTY_MOI_1090820.shp")
# Display data 顯示前5筆
County_data.head()
# Out:
#   COUNTYID COUNTYCODE COUNTYNAME          COUNTYENG  \
# 0        Z      09007        連江縣  Lienchiang County
# 1        G      10002        宜蘭縣       Yilan County
# 2        N      10007        彰化縣    Changhua County
# 3        M      10008        南投縣      Nantou County
# 4        P      10009        雲林縣      Yunlin County
#
#                                             geometry
# 0  MULTIPOLYGON (((119.96445 25.94552, 119.96427 ...
# 1  MULTIPOLYGON (((121.95971 24.84494, 121.96064 ...
# 2  POLYGON ((120.45655 24.20719, 120.48589 24.197...
# 3  POLYGON ((121.27086 24.23661, 121.27108 24.236...
# 4  MULTIPOLYGON (((120.08108 23.52412, 120.08161 ...

# %%
## plot data
Sample_data = County_data.loc[:, ['COUNTYNAME', 'geometry']]
Sample_data.plot()
# Out:
# <AxesSubplot:>

# %%
County_data=County_data.to_crs(epsg=3826)
Sample_data = County_data.loc[:, ['COUNTYNAME', 'geometry']]
Sample_data.plot()
# Out:
# <AxesSubplot:>

# %%
# 鄉鎮市區界
Town_data = gpd.read_file("C:/Users/Huwalli/OneDrive/文件/GitHub/eduproject/Town_data.csv", encoding='utf-8')

Town_data.head()
# Out:
#   Column1 TOWNID  TOWNCODE COUNTYNAME population             TOWNENG COUNTYID  \
# 0       0    V02  10014020        臺東縣       1000  Chenggong Township        V
# 1       1    T21  10013210        屏東縣       1001    Jiadong Township        T
# 2       2    P13  10009130        雲林縣       1002    Mailiao Township        P
# 3       3    V11  10014110        臺東縣       1003      Lüdao Township        V
# 4       4    V16  10014160        臺東縣       1004      Lanyu Township        V
#
#   COUNTYCODE geometry
# 0      10014     None
# 1      10013     None
# 2      10009     None
# 3      10014     None
# 4      10014     None

# %%
type(Town_data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
Town_data.drop(columns=['geometry'], inplace=True)
Town_data
# Out:
#     Column1 TOWNID  TOWNCODE COUNTYNAME population             TOWNENG  \
# 0         0    V02  10014020        臺東縣       1000  Chenggong Township
# 1         1    T21  10013210        屏東縣       1001    Jiadong Township
# 2         2    P13  10009130        雲林縣       1002    Mailiao Township
# 3         3    V11  10014110        臺東縣       1003      Lüdao Township
# 4         4    V16  10014160        臺東縣       1004      Lanyu Township
# ..      ...    ...       ...        ...        ...                 ...
# 363     363    U12  10015120        花蓮縣       1363    Wanrong Township
# 364     364    H09  68000090        桃園市       1364    Longtan District
# 365     365    H10  68000100        桃園市       1365   Pingzhen District
# 366     366    A13  63000090        臺北市       1366    Nangang District
# 367     367    A14  63000100        臺北市       1367      Neihu District
#
#     COUNTYID COUNTYCODE
# 0          V      10014
# 1          T      10013
# 2          P      10009
# 3          V      10014
# 4          V      10014
# ..       ...        ...
# 363        U      10015
# 364        H      68000
# 365        H      68000
# 366        A      63000
# 367        A      63000
#
# [368 rows x 8 columns]

# %%
Big_Taipei = Town_data[(Town_data['COUNTYNAME']=='臺北市') | (Town_data['COUNTYNAME']=='新北市')]
Big_Taipei
# Out:
#     Column1 TOWNID  TOWNCODE COUNTYNAME population              TOWNENG  \
# 152     152    A02  63000030        臺北市       1152       Da'an District
# 153     153    A11  63000080        臺北市       1153     Wenshan District
# 209     209    F33  65000040        新北市       1209      Yonghe District
# 210     210    F07  65000060        新北市       1210     Xindian District
# 211     211    F19  65000130        新北市       1211     Tucheng District
# 212     212    F04  65000140        新北市       1212      Luzhou District
# 213     213    F03  65000150        新北市       1213        Wugu District
# 214     214    F10  65000200        新北市       1214     Pinglin District
# 215     215    F22  65000240        新北市       1215      Pingxi District
# 216     216    F11  65000290        新北市       1216       Wulai District
# 256     256    F27  65000100        新北市       1256      Tamsui District
# 257     257    F21  65000120        新北市       1257     Ruifang District
# 258     258    F02  65000170        新北市       1258      Linkou District
# 259     259    F30  65000210        新北市       1259      Sanzhi District
# 260     260    F32  65000230        新北市       1260        Bali District
# 296     296    F15  65000090        新北市       1296      Sanxia District
# 297     297    F16  65000080        新北市       1297      Yingge District
# 298     298    F18  65000030        新北市       1298     Zhonghe District
# 299     299    F17  65000070        新北市       1299      Shulin District
# 300     300    F09  65000180        新北市       1300    Shenkeng District
# 301     301    F14  65000010        新北市       1301     Banqiao District
# 302     302    F08  65000190        新北市       1302     Shiding District
# 303     303    F01  65000050        新北市       1303   Xinzhuang District
# 304     304    F06  65000160        新北市       1304     Taishan District
# 305     305    F05  65000020        新北市       1305    Sanchong District
# 306     306    F23  65000250        新北市       1306    Shuangxi District
# 307     307    F24  65000260        新北市       1307    Gongliao District
# 308     308    F28  65000110        新北市       1308       Xizhi District
# 309     309    F26  65000280        新北市       1309       Wanli District
# 310     310    F25  65000270        新北市       1310     Jinshan District
# 311     311    F31  65000220        新北市       1311      Shimen District
# 333     333    A17  63000020        臺北市       1333       Xinyi District
# 334     334    A05  63000070        臺北市       1334      Wanhua District
# 335     335    A03  63000050        臺北市       1335  Zhongzheng District
# 336     336    A01  63000010        臺北市       1336    Songshan District
# 337     337    A09  63000060        臺北市       1337      Datong District
# 338     338    A10  63000040        臺北市       1338   Zhongshan District
# 339     339    A15  63000110        臺北市       1339      Shilin District
# 340     340    A16  63000120        臺北市       1340      Beitou District
# 366     366    A13  63000090        臺北市       1366     Nangang District
# 367     367    A14  63000100        臺北市       1367       Neihu District
#
#     COUNTYID COUNTYCODE
# 152        A      63000
# 153        A      63000
# 209        F      65000
# 210        F      65000
# 211        F      65000
# 212        F      65000
# 213        F      65000
# 214        F      65000
# 215        F      65000
# 216        F      65000
# 256        F      65000
# 257        F      65000
# 258        F      65000
# 259        F      65000
# 260        F      65000
# 296        F      65000
# 297        F      65000
# 298        F      65000
# 299        F      65000
# 300        F      65000
# 301        F      65000
# 302        F      65000
# 303        F      65000
# 304        F      65000
# 305        F      65000
# 306        F      65000
# 307        F      65000
# 308        F      65000
# 309        F      65000
# 310        F      65000
# 311        F      65000
# 333        A      63000
# 334        A      63000
# 335        A      63000
# 336        A      63000
# 337        A      63000
# 338        A      63000
# 339        A      63000
# 340        A      63000
# 366        A      63000
# 367        A      63000

# %%
import numpy as np
for i in Big_Taipei['population'].index:
    Big_Taipei.loc[i, 'population'] = np.int64(Big_Taipei.loc[i, 'population'])
# Out:
# C:\Users\Huwalli\AppData\Local\Temp\ipykernel_21576\2851144523.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Big_Taipei.loc[i, 'population'] = np.int64(Big_Taipei.loc[i, 'population'])

# %%
type(Big_Taipei['population'][152])
# Out:
# numpy.int64

# %%
# 檢查 population 列是否存在缺失值
missing_values = Big_Taipei['population'].isnull().sum()
if missing_values > 0:
    print("population 列中存在缺失值。")
    # 處理缺失值的方法，例如填充或刪除缺失值
    # Big_Taipei['population'] = Big_Taipei['population'].fillna(0)  # 填充缺失值為 0
    # Big_Taipei.dropna(subset=['population'], inplace=True)  # 刪除缺失值的行
else:
    print("population 列中不存在缺失值。")
# Out:
# population 列中不存在缺失值。

# %%
County_data[['COUNTYNAME', 'geometry']]
# Out:
#    COUNTYNAME                                           geometry
# 0         連江縣  MULTIPOLYGON (((119.96445 25.94552, 119.96427 ...
# 1         宜蘭縣  MULTIPOLYGON (((121.95971 24.84494, 121.96064 ...
# 2         彰化縣  POLYGON ((120.45655 24.20719, 120.48589 24.197...
# 3         南投縣  POLYGON ((121.27086 24.23661, 121.27108 24.236...
# 4         雲林縣  MULTIPOLYGON (((120.08108 23.52412, 120.08161 ...
# 5         基隆市  MULTIPOLYGON (((121.71015 25.17604, 121.71015 ...
# 6         臺北市  POLYGON ((121.57098 25.19717, 121.57097 25.197...
# 7         新北市  POLYGON ((121.53752 25.30003, 121.53768 25.300...
# 8         臺中市  POLYGON ((121.32834 24.43304, 121.32845 24.432...
# 9         臺南市  POLYGON ((120.44025 23.41308, 120.44040 23.413...
# 10        桃園市  POLYGON ((121.26381 25.12198, 121.26668 25.120...
# 11        苗栗縣  POLYGON ((121.00820 24.64432, 121.00828 24.644...
# 12        嘉義市  POLYGON ((120.44758 23.51819, 120.44767 23.518...
# 13        嘉義縣  MULTIPOLYGON (((120.15192 23.39274, 120.15250 ...
# 14        金門縣  MULTIPOLYGON (((118.23381 24.16277, 118.23405 ...
# 15        高雄市  MULTIPOLYGON (((114.36173 10.37280, 114.36174 ...
# 16        臺東縣  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# 17        花蓮縣  POLYGON ((121.63127 24.37049, 121.63144 24.370...
# 18        澎湖縣  MULTIPOLYGON (((119.44025 23.22137, 119.44040 ...
# 19        新竹市  POLYGON ((120.92532 24.85478, 120.92545 24.854...
# 20        新竹縣  POLYGON ((121.03813 24.94638, 121.03822 24.946...
# 21        屏東縣  MULTIPOLYGON (((120.82649 21.75615, 120.82646 ...

# %%
# 將 'geometry' 列重新命名為 'county_geometry'
County_data = County_data.rename(columns={'geometry': 'county_geometry'})

# 合併 'Town_data' 和 'County_data'
merged_data = Town_data.merge(County_data[['COUNTYNAME', 'county_geometry']], on='COUNTYNAME', how='left')

# 將合併後的 'county_geometry' 列的值插入 'Town_data' 的 'geometry' 列
merged_data['geometry'] = merged_data['county_geometry']

# 刪除多餘的 'county_geometry' 列
merged_data.drop(['county_geometry'], axis=1, inplace=True)

# 顯示合併後的 GeoDataFrame
merged_data
# Out:
#     Column1 TOWNID  TOWNCODE COUNTYNAME population             TOWNENG  \
# 0         0    V02  10014020        臺東縣       1000  Chenggong Township
# 1         1    T21  10013210        屏東縣       1001    Jiadong Township
# 2         2    P13  10009130        雲林縣       1002    Mailiao Township
# 3         3    V11  10014110        臺東縣       1003      Lüdao Township
# 4         4    V16  10014160        臺東縣       1004      Lanyu Township
# ..      ...    ...       ...        ...        ...                 ...
# 363     363    U12  10015120        花蓮縣       1363    Wanrong Township
# 364     364    H09  68000090        桃園市       1364    Longtan District
# 365     365    H10  68000100        桃園市       1365   Pingzhen District
# 366     366    A13  63000090        臺北市       1366    Nangang District
# 367     367    A14  63000100        臺北市       1367      Neihu District
#
#     COUNTYID COUNTYCODE                                           geometry
# 0          V      10014  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# 1          T      10013  MULTIPOLYGON (((120.82649 21.75615, 120.82646 ...
# 2          P      10009  MULTIPOLYGON (((120.08108 23.52412, 120.08161 ...
# 3          V      10014  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# 4          V      10014  MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# ..       ...        ...                                                ...
# 363        U      10015  POLYGON ((121.63127 24.37049, 121.63144 24.370...
# 364        H      68000  POLYGON ((121.26381 25.12198, 121.26668 25.120...
# 365        H      68000  POLYGON ((121.26381 25.12198, 121.26668 25.120...
# 366        A      63000  POLYGON ((121.57098 25.19717, 121.57097 25.197...
# 367        A      63000  POLYGON ((121.57098 25.19717, 121.57097 25.197...
#
# [368 rows x 9 columns]

# %%
merged_data['geometry']
# Out:
# 0      MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# 1      MULTIPOLYGON (((120.82649 21.75615, 120.82646 ...
# 2      MULTIPOLYGON (((120.08108 23.52412, 120.08161 ...
# 3      MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
# 4      MULTIPOLYGON (((121.61180 21.94290, 121.61133 ...
#                              ...
# 363    POLYGON ((121.63127 24.37049, 121.63144 24.370...
# 364    POLYGON ((121.26381 25.12198, 121.26668 25.120...
# 365    POLYGON ((121.26381 25.12198, 121.26668 25.120...
# 366    POLYGON ((121.57098 25.19717, 121.57097 25.197...
# 367    POLYGON ((121.57098 25.19717, 121.57097 25.197...
# Name: geometry, Length: 368, dtype: geometry

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# 將資料轉換為 GeoDataFrame，並將 'geometry' 列重新命名為 'geom'
gdf = gpd.GeoDataFrame(merged_data, geometry='geometry')
gdf.rename_geometry('geom', inplace=True)

# 畫出地圖
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
gdf.plot(column='population', cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)

# 添加標題
plt.title('Population Distribution', fontdict={'fontsize': '15', 'fontweight' : '3'})

# 顯示圖表
plt.show()
